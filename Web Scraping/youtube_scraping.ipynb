# %%
from urllib.request import Request, urlopen
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
import requests

# %%
user = input("Enter the keyword:")
# qstr = quote_plus(user)
# print(qstr)
# req = requests.get("https://m.youtube.com/results?search_query={0}".format(qstr),headers={'User-Agent': 'Mozilla/5.0'})
# page = req.text
# soup=BeautifulSoup(page,'html.parser')
# webpage = urlopen(req).read()
# soup = BeautifulSoup(req,'lxml')
qstr1  = quote_plus(user)
req1 = Request("https://m.youtube.com/results?search_query={0}".format(qstr1), headers={'User-Agent': 'Brave/0.37.3'})
webpage1 = urlopen(req1).read()
soup = BeautifulSoup(webpage1)

# url = "https://m.youtube.com/results?search_query=machine"
# response = requests.get(url)
# soup = BeautifulSoup(response.content)
# response.close()
# Out:
# Enter the keyword:nlp

# %%
print (soup.prettify())

# %%
soup.findAll("div", "yt-lockup-video")

# %% [markdown]
# ## chname

# %%
# chname=[]
# for v in soup.findAll('a',attrs={'class':'yt-uix-sessionlink'}):
#     print(v)
#     chname.append(tmp)
# chname = chname[1:]

# %%
xy = soup.findAll("div", "yt-lockup-byline")
xy = xy[0:18]
xy
# Out:
# [<div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CF0Q3DAYACITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCO5QSoES5yn2Dw7YixDYT5Q">Aperture</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFwQ3DAYASITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCnxGkOGNMqQEUMvroOWps6Q">JRE Clips</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFsQ3DAYAiITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/TEDxTalks">TEDx Talks</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFoQ3DAYAyITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UC2U_ApECr-ifnTu9GIHcAEg">Reddit Storytime</a></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFkQ3DAYBCITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/edurekaIN">edureka!</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFgQ3DAYBSITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCCrbwIuhiZRF58Zsuu7849Q">Nserve</a></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFcQ3DAYBiITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/LondonRealTV">London Real</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFYQ3DAYByITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCnxGkOGNMqQEUMvroOWps6Q">JRE Clips</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFUQ3DAYCCITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/coldfustion">ColdFusion</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFQQ3DAYCSITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCdZ0V89JCjTV7_OagiJ3mJw">ED DocumentaryTV</a></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFMQ3DAYCiITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/AlJazeeraEnglish">Al Jazeera English</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFIQ3DAYCyITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/TEDxTalks">TEDx Talks</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CFAQ3DAYDCITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCO5QSoES5yn2Dw7YixDYT5Q">Aperture</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CE4Q3DAYDSITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/worldsciencefestival">World Science Festival</a></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CEwQ3DAYDiITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCzueCs6O4TKIcLM11ffrAOA">Wall Street Mozart</a></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CEsQ3DAYDyITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/TEDxTalks">TEDx Talks</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CEoQ3DAYECITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/channel/UCmLQqA5g62GIfQa9oME05wQ">Origins Explained</a></div>,
#  <div class="yt-lockup-byline "><a class="yt-uix-sessionlink spf-link " data-sessionlink="itct=CEkQ3DAYESITCNqqv7-lrOMCFUV2mAod1MQMlQ" href="/user/truedocumentaryhd">ADVEXON TV</a> <span class="yt-uix-tooltip yt-channel-title-icon-verified yt-sprite" title="Verified"></span></div>]

# %%
def chname():
  xy = soup.findAll("div", "yt-lockup-byline")
  xy = xy[0:18]
  chname1=[]
  for v in xy:
      tmp = v.find('a',attrs={'class':'yt-uix-sessionlink'}).text
      chname1.append(tmp)
  # chname = chname[1:]
  return chname1

# %%
chname()
# Out:
# ['MindMaster.TV',
#  'TEDx Talks',
#  'Project Life Mastery',
#  'Life Mastery Gym',
#  'Bay Area NLP And Hypnosis',
#  'Anthony Beardsell',
#  'edureka!',
#  'IntraAwareness',
#  'Anthony Beardsell',
#  'coachingnlptraining',
#  'Anthony Beardsell',
#  'NLPLife',
#  'Life Mastery Gym',
#  'NLPAcademy',
#  'stanfordonline',
#  'David Snyder',
#  'David Snyder',
#  'Life Mastery Gym']

# %%
# chname1=[]
# for v in chname:
#     tmp = v.find('a',attrs={"class":"yt-uix-sessionlink"}).text
#     chname1.append(tmp)
# chname1

# %% [markdown]
# ## Video links

# %%
vids = soup.findAll('a',class_='yt-uix-tile-link')
vids = vids[1:]
vids
# Out:
# [<a aria-describedby="description-id-616687" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEgQ3DAYASITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=syvKeNKww_Y" rel="spf-prefetch" title="Neuro Linguistic Programming | Ram Verma | TEDxFORESchool">Neuro Linguistic Programming | Ram Verma | TEDxFORESchool</a>,
#  <a aria-describedby="description-id-63628" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEcQ3DAYAiITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=5ecLYP3FE6g" rel="spf-prefetch" title="NLP Training &amp; Techniques: How To Use Neuro Linguistic Programming To Change Your Life">NLP Training &amp; Techniques: How To Use Neuro Linguistic Programming To Change Your Life</a>,
#  <a aria-describedby="description-id-41927" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEYQ3DAYAyITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=MIl3WGKVBn4" rel="spf-prefetch" title="Neuro Linguistic Programming Techniques You Can Use Instantly">Neuro Linguistic Programming Techniques You Can Use Instantly</a>,
#  <a aria-describedby="description-id-884474" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEUQ3DAYBCITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=MQiMFs2SIFk" rel="spf-prefetch" title="What is NLP &amp; How Does It Work?  Neuro Linguistic Programming Basics">What is NLP &amp; How Does It Work?  Neuro Linguistic Programming Basics</a>,
#  <a aria-describedby="description-id-309866" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEQQ3DAYBSITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=DyRfpod2fxw" rel="spf-prefetch" title="Swish Pattern - NLP Techniques">Swish Pattern - NLP Techniques</a>,
#  <a aria-describedby="description-id-666611" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEMQ3DAYBiITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=5ctbvkAMQO4" rel="spf-prefetch" title="Natural Language Processing In 10 Minutes | NLP Tutorial For Beginners | NLP Training | Edureka">Natural Language Processing In 10 Minutes | NLP Tutorial For Beginners | NLP Training | Edureka</a>,
#  <a aria-describedby="description-id-947752" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEIQ3DAYByITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=Gfp5absKF94" rel="spf-prefetch" title="FREE NLP Training - Live Seminar with Demonstrations">FREE NLP Training - Live Seminar with Demonstrations</a>,
#  <a aria-describedby="description-id-720337" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEEQ3DAYCCITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=NghY51I6RA4" rel="spf-prefetch" title="How to lose weight using NLP">How to lose weight using NLP</a>,
#  <a aria-describedby="description-id-120568" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CEAQ3DAYCSITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=ANY8-_kqCZQ" rel="spf-prefetch" title="Training NLP with Tony Robbins">Training NLP with Tony Robbins</a>,
#  <a aria-describedby="description-id-110516" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CD8Q3DAYCiITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=EGe1deya3uU" rel="spf-prefetch" title="What is NLP? How can it help me?">What is NLP? How can it help me?</a>,
#  <a aria-describedby="description-id-502927" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CD4Q3DAYCyITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=Z_RQxt0Wcgk" rel="spf-prefetch" title="Richard Bandler (co-creator of NLP) Overcoming bad memories. LIVE demo.">Richard Bandler (co-creator of NLP) Overcoming bad memories. LIVE demo.</a>,
#  <a aria-describedby="description-id-582843" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CD0Q3DAYDCITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=DhB9fE-TQow" rel="spf-prefetch" title="3 NLP Techniques You Must Know">3 NLP Techniques You Must Know</a>,
#  <a aria-describedby="description-id-768408" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDwQ3DAYDSITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=t5eSo4mgQ4g" rel="spf-prefetch" title="Back to Basics; NLP Fundamentals">Back to Basics; NLP Fundamentals</a>,
#  <a aria-describedby="description-id-529933" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDsQ3DAYDiITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=8rXD5-xhemo" rel="spf-prefetch" title="Stanford CS224N: NLP with Deep Learning | Winter 2019 | Lecture 1 – Introduction and Word Vectors">Stanford CS224N: NLP with Deep Learning | Winter 2019 | Lecture 1 – Introduction and Word Vectors</a>,
#  <a aria-describedby="description-id-325884" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDoQ3DAYDyITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=ui7h8CTSD_8" rel="spf-prefetch" title="NLP LECTURE: SPEED ATTRACTION- How To Make Someone Love You In 20 Minutes Or Less">NLP LECTURE: SPEED ATTRACTION- How To Make Someone Love You In 20 Minutes Or Less</a>,
#  <a aria-describedby="description-id-348722" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDkQ3DAYECITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=IvO8ZsQYUK0" rel="spf-prefetch" title="NLP TRAINING: How To Program Your Subconscious Mind To Use The Law of Attraction">NLP TRAINING: How To Program Your Subconscious Mind To Use The Law of Attraction</a>,
#  <a aria-describedby="description-id-673177" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDgQ3DAYESITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=7_Xh4MPCGRk" rel="spf-prefetch" title="NLP Techniques: One Simple Phrase To Overcome Resistance">NLP Techniques: One Simple Phrase To Overcome Resistance</a>,
#  <a aria-describedby="description-id-13475" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDcQ3DAYEiITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=fTbHxJcxH3U" rel="spf-prefetch" title="Neuro Linguistic Programming audiobook by Adam Hunter">Neuro Linguistic Programming audiobook by Adam Hunter</a>,
#  <a aria-describedby="description-id-367728" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CDAQ3DAYFCITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=qcnjuJliu-k" rel="spf-prefetch" title="The master of nlp watch it">The master of nlp watch it</a>,
#  <a aria-describedby="description-id-14932" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CC8Q3DAYFSITCOCgn4vw9eMCFVS_xAodow8CEDIGc2VhcmNoUgNubHA" dir="ltr" href="/watch?v=05ONoGfmKvA" rel="spf-prefetch" title="Natural Language Processing (NLP) &amp; Text Mining Tutorial Using NLTK | NLP Training | Edureka">Natural Language Processing (NLP) &amp; Text Mining Tutorial Using NLTK | NLP Training | Edureka</a>]

# %%
def videourl():
  videourl=[]
  for v in vids:
      tmp = v['href']
      videourl.append(tmp)
  return videourl

# %%
videourl()
# Out:
# ['/watch?v=syvKeNKww_Y',
#  '/watch?v=5ecLYP3FE6g',
#  '/watch?v=MIl3WGKVBn4',
#  '/watch?v=MQiMFs2SIFk',
#  '/watch?v=DyRfpod2fxw',
#  '/watch?v=5ctbvkAMQO4',
#  '/watch?v=Gfp5absKF94',
#  '/watch?v=NghY51I6RA4',
#  '/watch?v=ANY8-_kqCZQ',
#  '/watch?v=EGe1deya3uU',
#  '/watch?v=Z_RQxt0Wcgk',
#  '/watch?v=DhB9fE-TQow',
#  '/watch?v=t5eSo4mgQ4g',
#  '/watch?v=8rXD5-xhemo',
#  '/watch?v=ui7h8CTSD_8',
#  '/watch?v=IvO8ZsQYUK0',
#  '/watch?v=7_Xh4MPCGRk',
#  '/watch?v=fTbHxJcxH3U',
#  '/watch?v=qcnjuJliu-k',
#  '/watch?v=05ONoGfmKvA']

# %% [markdown]
# ## video title

# %%
def videotitle():
  videotitle=[]
  for v in vids:
      tmp =  v['title']
      videotitle.append(tmp)
  return videotitle

# %%
videotitle()
# Out:
# ['Neuro Linguistic Programming | Ram Verma | TEDxFORESchool',
#  'NLP Training & Techniques: How To Use Neuro Linguistic Programming To Change Your Life',
#  'Neuro Linguistic Programming Techniques You Can Use Instantly',
#  'What is NLP & How Does It Work?  Neuro Linguistic Programming Basics',
#  'Swish Pattern - NLP Techniques',
#  'Natural Language Processing In 10 Minutes | NLP Tutorial For Beginners | NLP Training | Edureka',
#  'FREE NLP Training - Live Seminar with Demonstrations',
#  'How to lose weight using NLP',
#  'Training NLP with Tony Robbins',
#  'What is NLP? How can it help me?',
#  'Richard Bandler (co-creator of NLP) Overcoming bad memories. LIVE demo.',
#  '3 NLP Techniques You Must Know',
#  'Back to Basics; NLP Fundamentals',
#  'Stanford CS224N: NLP with Deep Learning | Winter 2019 | Lecture 1 – Introduction and Word Vectors',
#  'NLP LECTURE: SPEED ATTRACTION- How To Make Someone Love You In 20 Minutes Or Less',
#  'NLP TRAINING: How To Program Your Subconscious Mind To Use The Law of Attraction',
#  'NLP Techniques: One Simple Phrase To Overcome Resistance',
#  'Neuro Linguistic Programming audiobook by Adam Hunter',
#  'The master of nlp watch it',
#  'Natural Language Processing (NLP) & Text Mining Tutorial Using NLTK | NLP Training | Edureka']

# %%
# !pip install PyGithub
# Out:
# Collecting PyGithub
#   Downloading https://files.pythonhosted.org/packages/13/66/5c510242526d162708ffc0c82fd5ba647886f07d7abcae8587adeec86411/PyGithub-1.43.8.tar.gz (108kB)
#      |████████████████████████████████| 112kB 2.8MB/s
# Collecting deprecated (from PyGithub)
#   Downloading https://files.pythonhosted.org/packages/88/0e/9d5a1a8cd7130c49334cce7b8167ceda63d6a329c8ea65b626116bc9e9e6/Deprecated-1.2.6-py2.py3-none-any.whl
# Collecting pyjwt (from PyGithub)
#   Downloading https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.6/dist-packages (from PyGithub) (2.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.6/dist-packages (from deprecated->PyGithub) (1.11.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->PyGithub) (2.8)
# Building wheels for collected packages: PyGithub
#   Building wheel for PyGithub (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/ba/9a/c3/d8a3dd0f2574b8fd4c43fea45385773c3bcbb1cae80d05f9ed
# Successfully built PyGithub
# Installing collected packages: deprecated, pyjwt, PyGithub
# Successfully installed PyGithub-1.43.8 deprecated-1.2.6 pyjwt-1.7.1

# %%
# from apiclient.discovery import build
# from apiclient.errors import HttpError
from oauth2client.tools import argparser
from urllib.request import Request, urlopen
from urllib.parse import quote
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from github import Github  
import time
start_time = time.time()

g = Github("01f85a96bbfef290b6dba07a32e2e88afcd41e9c")

DEVELOPER_KEY = "AIzaSyA800IGgDgQ1kwXSC6A4WctAzW05UEhHAU"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

class Test:

  def med_links(self,x):
    self.x=x
    links = []
    for data in x:
      for a in data.find_all('a'):
          links.append(a.get('href')) 
    return (links)

  def clapcount(self,z):
    clapcount = []
    self.z=z 
    for node in z:
        clapcount.append(''.join(node.findAll(text=True)))
    return (clapcount)

  def med_titles(self,k):
    self.k=k
    titles = []
    for node in k:
        titles.append(''.join(node.findAll(text=True)))
    return (titles)
  
  def videotitle(self,vids):                         # youtube
    self.vids = vids
    videotitle=[]
    for v in vids:
        tmp =  v['title']
        videotitle.append(tmp)
    return videotitle
  
  def videourl(self,vids):
    self.vids = vids
    videourl=[]
    for v in vids:
        tmp = 'https://www.youtube.com' + v['href']
        videourl.append(tmp)
    return videourl
  
  def chname(self,xy):
    self.xy = xy
    chname1=[]
    for v in xy:
        tmp = v.find('a',attrs={'class':'yt-uix-sessionlink'}).text
        chname1.append(tmp)
    # chname = chname[1:]
    return chname1
  
  
    
      
  # Code with Papers functions
  def cop_desc(self,a):
    self.a = a
    desc = []
    for i in a:
      desc.append(i.find('p',attrs={'class':'item-strip-abstract'}).text)
    return desc
  
  def cop_codelinks(self,b):
    code = []
    github_code = []
    self.b = b
    
    for i in b:
      code.append( i.find('a',attrs={'class':'badge badge-dark'})['href'])

    base_url = 'https://paperswithcode.com'

    for i in range(len(code)):
      github_code.append('https://paperswithcode.com{}'.format(code[i]))
    return github_code
  
  def cop_titles(self,c):
    titles = []
    self.c = c
    for node in c:
        titles.append(''.join(node.findAll(text=True)))
    titles1 = titles[1:] # Because of the first content is coming as a str "Search Result"
    return titles1
  
  def html_urls(self,repos12):
    self.repos12 = repos12

    html_urls = []
    for i in repos12:
      html_urls.append(i.html_url)
    return html_urls

  def starslist(self,repos_name):
    self.repos_name = repos_name
    starslist1 = []
    for i in range(len(repos_name)):
          starslist = g.get_repo(repos_name[i])
          starslist1.append(starslist.stargazers_count)
    return starslist1


class Sol:
  ob=Test()
  user = str(input("Enter the Keyword:"))
  print(user)
  qstr = quote(str(user))#%20
  req = Request('https://medium.com/search?q={0}'.format(qstr), headers={'User-Agent': 'Mozilla/5.0'})
  webpage = urlopen(req).read()
  soup = BeautifulSoup(webpage)
  
  ## for code with papers
  qstr1  = quote_plus(user)#+
  req1 = Request('https://paperswithcode.com/search?q={0}'.format(qstr1), headers={'User-Agent': 'Mozilla/5.0'})
  webpage1 = urlopen(req1).read()
  soup1 = BeautifulSoup(webpage1)
  
  ## for Youtube
  qstr2  = quote_plus(user)
  req2 = Request("https://m.youtube.com/results?search_query={0}".format(qstr2), headers={'User-Agent': 'Mozilla/5.0'})
  webpage2 = urlopen(req2).read()
  soup2 = BeautifulSoup(webpage2)
  
  
  ## Github 
  repositories = g.search_repositories(query='topic:{0}'.format(user)) #need to solve for break iteraton
  
  try:
    repos =[]
    for repo in repositories:
        repos.append(repo.full_name)
    repos_name = repos[0:50]
  except Exception as ex:
    repos_name = repos[0:50]
     
  try:
    repos1 = []
    for repo in repositories:
        repos1.append(repo)
    repos12 = repos1[0:50]
  except Exception as ex:
    repos12 = repos1[0:50]
  
  y=soup.find_all('div',attrs= {'class':'postArticle-content'})
  x1=soup.findAll('span',attrs={'class':'u-relative u-background js-actionMultirecommendCount u-marginLeft5'})
  x2=soup.findAll('div',attrs={'class':'section-inner sectionLayout--insetColumn'})
  
  xy = soup2.findAll("div", "yt-lockup-byline")
  xy = xy[0:18]
  vids = soup2.findAll('a',attrs={'class':'yt-uix-tile-link'})
 
  res=ob.med_links(y)
  res1=ob.clapcount(x1)
  res2=ob.med_titles(x2)
 
  you1 = ob.videotitle(vids)
  you2 = ob.videourl(vids)
  you3 = ob.chname(xy)
  
  cop_desc = soup1.findAll('div',attrs={'class':'col-lg-9 item-content'})
  cop_codelinks =soup1.findAll('div',attrs={'class':'entity'})
  cop_titles = soup1.findAll('h1')
  
  cop1 = ob.cop_desc(cop_desc)
  cop2 = ob.cop_codelinks(cop_codelinks)
  cop3 = ob.cop_titles(cop_titles)
  
  a = ob.html_urls(repos12)
  b = ob.starslist(repos_name)
  
  print("\n######################################################")
  print("\nMedium-website contents")
  print("\nFound {0} contents".format(len(res2)))
  print("\nMedium_titles",res2)
  print("Medium_clapcount",res1)
  print("Medium_links",res)
  print("\n######################################################")
  print("\nYoutube contents")
  print("\nFound {0} contents".format(len(you1)))
  print("\nYoutube_titles",you1)
  print("Youtube_links",you2)
  print("Youtube_ch_titles",you3)
  print("\n######################################################")
  print("\nCode with Papers contents")
  print("\nFound {0} contents".format(len(cop3)))
  print("\nCode with Papers_titles",cop3)
  print("Code with Papers_desc",cop1)
  print("Code with Papers_codelinks",cop2)
  print("\n######################################################")
  print("\nGithub contents")
  print("\nFound {0} contents".format(len(repos_name)))
  print("\nGithub_repos_name",repos_name)
  print("Github_links",a)
  print("Github_starlist",b)
  end_time = time.time()
  print(end_time-start_time)
# Out:
# Enter the Keyword:nlp
# nlp
#
# ######################################################
#
# Medium-website contents
#
# Found 10 contents
#
# Medium_titles ['How to solve 90% of NLP problems: a step-by-step guideUsing Machine Learning to understand and…', 'Over 150 of the Best Machine Learning, NLP, and Python Tutorials I’ve\xa0FoundBy popular demand, I’ve updated this article with the latest tutorials from the past 12 months. Check it out\xa0here', 'Machine Learning, NLP: Text Classification using scikit-learn, python and\xa0NLTK.', 'Over 200 of the Best Machine Learning, NLP, and Python Tutorials\u200a-\u200a2018\xa0EditionThere are dozens\xa0of…', 'Ultimate Guide to Leveraging NLP & Machine Learning for your\xa0ChatbotCode Snippets and Github Included', 'NLP\u200a—\u200aBuilding a Question Answering modelDoing cool things with data!', 'BERT Explained: State of the art language model for\xa0NLP', 'Learning Machine Learning and NLP from 187 Quora QuestionsIf you like this article, check out another by Robbie:My Curated List of AI and Machine Learning Resources', 'Lessons Learned from Applying Deep Learning for NLP Without Big\xa0Data', 'How to get started in\xa0NLPSomewhere I read that if you ever have to answer the same question twice, it’s probably a good idea to turn it…']
# Medium_clapcount ['17.9K', '9.7K', '5.3K', '4.4K', '2.6K', '3.1K', '2.6K', '1.4K', '2.2K', '1.7K']
# Medium_links ['https://blog.insightdatascience.com/how-to-solve-90-of-nlp-problems-a-step-by-step-guide-fda605278e4e?source=search_post---------0', 'https://medium.com/machine-learning-in-practice/over-150-of-the-best-machine-learning-nlp-and-python-tutorials-ive-found-ffce2939bd78?source=search_post---------1', 'https://towardsdatascience.com/machine-learning-nlp-text-classification-using-scikit-learn-python-and-nltk-c52b92a7c73a?source=search_post---------2', 'https://medium.com/machine-learning-in-practice/over-200-of-the-best-machine-learning-nlp-and-python-tutorials-2018-edition-dd8cf53cb7dc?source=search_post---------3', 'https://chatbotslife.com/ultimate-guide-to-leveraging-nlp-machine-learning-for-you-chatbot-531ff2dd870c?source=search_post---------4', 'https://towardsdatascience.com/nlp-building-a-question-answering-model-ed0529a68c54?source=search_post---------5', 'https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270?source=search_post---------6', 'https://medium.com/machine-learning-in-practice/learning-machine-learning-and-nlp-from-185-quora-questions-cebe42e47da8?source=search_post---------7', 'https://towardsdatascience.com/lessons-learned-from-applying-deep-learning-for-nlp-without-big-data-d470db4f27bf?source=search_post---------8', 'https://towardsdatascience.com/how-to-get-started-in-nlp-6a62aa4eaeff?source=search_post---------9']
#
# ######################################################
#
# Youtube contents
#
# Found 20 contents
#
# Youtube_titles ['NLP Training & Techniques: How To Use Neuro Linguistic Programming To Change Your Life', 'Neuro Linguistic Programming | Ram Verma | TEDxFORESchool', '3 NLP Techniques You Must Know', 'Back to Basics; NLP Fundamentals', 'What is NLP & How Does It Work?  Neuro Linguistic Programming Basics', 'Richard Bandler (co-creator of NLP) Overcoming bad memories. LIVE demo.', 'FREE NLP Training - Live Seminar with Demonstrations', 'How to lose weight using NLP', 'Natural Language Processing In 10 Minutes | NLP Tutorial For Beginners | NLP Training | Edureka', 'Swish Pattern - NLP Techniques', 'What is NLP? How can it help me?', 'Training NLP with Tony Robbins', 'NLP TRAINING: How To Program Your Subconscious Mind To Use The Law of Attraction', 'NLP Techniques: One Simple Phrase To Overcome Resistance', 'Natural Language Processing (NLP) & Text Mining Tutorial Using NLTK | NLP Training | Edureka', 'NLP LECTURE: SPEED ATTRACTION- How To Make Someone Love You In 20 Minutes Or Less', 'The master of nlp watch it', 'NLP Techniques: How to eliminate unwanted thoughts', 'Discover Your Love Strategy | NLP Strategy - Conversational Seminar with Demonstration', 'Neuro Linguistic Programming Techniques You Can Use Instantly']
# Youtube_links ['https://www.youtube.com/watch?v=5ecLYP3FE6g', 'https://www.youtube.com/watch?v=syvKeNKww_Y', 'https://www.youtube.com/watch?v=DhB9fE-TQow', 'https://www.youtube.com/watch?v=t5eSo4mgQ4g', 'https://www.youtube.com/watch?v=MQiMFs2SIFk', 'https://www.youtube.com/watch?v=Z_RQxt0Wcgk', 'https://www.youtube.com/watch?v=Gfp5absKF94', 'https://www.youtube.com/watch?v=NghY51I6RA4', 'https://www.youtube.com/watch?v=5ctbvkAMQO4', 'https://www.youtube.com/watch?v=DyRfpod2fxw', 'https://www.youtube.com/watch?v=EGe1deya3uU', 'https://www.youtube.com/watch?v=ANY8-_kqCZQ', 'https://www.youtube.com/watch?v=IvO8ZsQYUK0', 'https://www.youtube.com/watch?v=7_Xh4MPCGRk', 'https://www.youtube.com/watch?v=05ONoGfmKvA', 'https://www.youtube.com/watch?v=ui7h8CTSD_8', 'https://www.youtube.com/watch?v=qcnjuJliu-k', 'https://www.youtube.com/watch?v=f81dxIXADfc', 'https://www.youtube.com/watch?v=TwnQQRVd-H8', 'https://www.youtube.com/watch?v=MIl3WGKVBn4']
# Youtube_ch_titles ['Project Life Mastery', 'TEDx Talks', 'Life Mastery Gym', 'NLPAcademy', 'Bay Area NLP And Hypnosis', 'NLPLife', 'IntraAwareness', 'Anthony Beardsell', 'edureka!', 'Anthony Beardsell', 'Anthony Beardsell', 'coachingnlptraining', 'David Snyder', 'Life Mastery Gym', 'edureka!', 'David Snyder', 'Stefan Lux', 'NLPTimes']
#
# ######################################################
#
# Code with Papers contents
#
# Found 10 contents
#
# Code with Papers_titles ['FLAIR: An Easy-to-Use Framework for State-of-the-Art NLP', 'NeuronBlocks: Building Your NLP DNN Models Like Playing Lego', 'Mixed-Precision Training for NLP and Speech Recognition with OpenSeq2Seq', 'BERT Rediscovers the Classical NLP Pipeline', 'CogCompNLP: Your Swiss Army Knife for NLP', 'Probing What Different NLP Tasks Teach Machines about Function Word Comprehension', 'BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding', 'XLNet: Generalized Autoregressive Pretraining for Language Understanding', 'A Dataset of Peer Reviews (PeerRead): Collection, Insights and NLP Applications', 'AllenNLP: A Deep Semantic Natural Language Processing Platform']
# Code with Papers_desc ['We present FLAIR, an NLP framework designed to facilitate training and distribution of state-of-the-art sequence labeling, text classification and language models.', 'Deep Neural Networks (DNN) have been widely employed in industry to address various Natural Language Processing (NLP) tasks.', 'We present OpenSeq2Seq - a TensorFlow-based toolkit for training sequence-to-sequence models that features distributed and mixed-precision training.', 'Pre-trained text encoders have rapidly advanced the state of the art on many NLP tasks.', '', 'We introduce a set of nine challenge tasks that test for the understanding of function words.', 'We introduce a new language representation model called BERT, which stands for Bidirectional Encoder Representations from Transformers.', 'With the capability of modeling bidirectional contexts, denoising autoencoding based pretraining like BERT achieves better performance than pretraining approaches based on autoregressive language modeling.', 'In the first task, we show that simple models can predict whether a paper is accepted with up to 21% error reduction compared to the majority baseline.', 'This paper describes AllenNLP, a platform for research on deep learning methods in natural language understanding.']
# Code with Papers_codelinks ['https://paperswithcode.com/paper/flair-an-easy-to-use-framework-for-state-of#code', 'https://paperswithcode.com/paper/neuronblocks-building-your-nlp-dnn-models#code', 'https://paperswithcode.com/paper/mixed-precision-training-for-nlp-and-speech#code', 'https://paperswithcode.com/paper/bert-rediscovers-the-classical-nlp-pipeline#code', 'https://paperswithcode.com/paper/cogcompnlp-your-swiss-army-knife-for-nlp#code', 'https://paperswithcode.com/paper/probing-what-different-nlp-tasks-teach#code', 'https://paperswithcode.com/paper/bert-pre-training-of-deep-bidirectional#code', 'https://paperswithcode.com/paper/xlnet-generalized-autoregressive-pretraining#code', 'https://paperswithcode.com/paper/a-dataset-of-peer-reviews-peerread-collection#code', 'https://paperswithcode.com/paper/allennlp-a-deep-semantic-natural-language#code']
#
# ######################################################
#
# Github contents
#
# Found 50 contents
#
# Github_repos_name ['apachecn/AiLearning', 'google-research/bert', 'hankcs/HanLP', 'oxford-cs-deepnlp-2017/lectures', 'explosion/spaCy', 'virgili0/Virgilio', 'huggingface/pytorch-transformers', 'RaRe-Technologies/gensim', 'spencermountain/compromise', 'chiphuyen/stanford-tensorflow-tutorials', 'keon/awesome-nlp', 'nltk/nltk', 'bharathgs/Awesome-pytorch-list', 'zalandoresearch/flair', 'allenai/allennlp', 'stanfordnlp/CoreNLP', 'sloria/TextBlob', 'RasaHQ/rasa', 'NLPchina/ansj_seg', 'nfmcclure/tensorflow_cookbook', 'brightmart/text_classification', 'hanxiao/bert-as-service', 'crownpku/Awesome-Chinese-NLP', 'zihangdai/xlnet', 'vi3k6i5/flashtext', 'graykode/nlp-tutorial', 'MycroftAI/mycroft-core', 'spro/practical-pytorch', 'deepmipt/DeepPavlov', 'kelaberetiv/TagUI', 'brightmart/nlp_chinese_corpus', 'wooorm/franc', 'jadore801120/attention-is-all-you-need-pytorch', 'axa-group/nlp.js', 'snipsco/snips-nlu', 'codertimo/BERT-pytorch', 'Kyubyong/nlp_tasks', 'openvenues/libpostal', 'RasaHQ/rasa_core', 'stanfordnlp/stanfordnlp', 'HIT-SCIR/ltp', 'DSKSD/DeepNLP-models-Pytorch', 'jdkato/prose', 'NervanaSystems/nlp-architect', 'koth/kcws', 'thisandagain/sentiment', 'endymecy/awesome-deeplearning-resources', 'aleju/papers', 'baidu/Familia', 'pytorch/text']
# Github_links ['https://github.com/apachecn/AiLearning', 'https://github.com/google-research/bert', 'https://github.com/hankcs/HanLP', 'https://github.com/oxford-cs-deepnlp-2017/lectures', 'https://github.com/explosion/spaCy', 'https://github.com/virgili0/Virgilio', 'https://github.com/huggingface/pytorch-transformers', 'https://github.com/RaRe-Technologies/gensim', 'https://github.com/spencermountain/compromise', 'https://github.com/chiphuyen/stanford-tensorflow-tutorials', 'https://github.com/keon/awesome-nlp', 'https://github.com/nltk/nltk', 'https://github.com/bharathgs/Awesome-pytorch-list', 'https://github.com/zalandoresearch/flair', 'https://github.com/allenai/allennlp', 'https://github.com/stanfordnlp/CoreNLP', 'https://github.com/sloria/TextBlob', 'https://github.com/RasaHQ/rasa', 'https://github.com/NLPchina/ansj_seg', 'https://github.com/nfmcclure/tensorflow_cookbook', 'https://github.com/brightmart/text_classification', 'https://github.com/hanxiao/bert-as-service', 'https://github.com/crownpku/Awesome-Chinese-NLP', 'https://github.com/zihangdai/xlnet', 'https://github.com/vi3k6i5/flashtext', 'https://github.com/graykode/nlp-tutorial', 'https://github.com/MycroftAI/mycroft-core', 'https://github.com/spro/practical-pytorch', 'https://github.com/deepmipt/DeepPavlov', 'https://github.com/kelaberetiv/TagUI', 'https://github.com/brightmart/nlp_chinese_corpus', 'https://github.com/wooorm/franc', 'https://github.com/jadore801120/attention-is-all-you-need-pytorch', 'https://github.com/axa-group/nlp.js', 'https://github.com/snipsco/snips-nlu', 'https://github.com/codertimo/BERT-pytorch', 'https://github.com/Kyubyong/nlp_tasks', 'https://github.com/openvenues/libpostal', 'https://github.com/RasaHQ/rasa_core', 'https://github.com/stanfordnlp/stanfordnlp', 'https://github.com/HIT-SCIR/ltp', 'https://github.com/DSKSD/DeepNLP-models-Pytorch', 'https://github.com/jdkato/prose', 'https://github.com/NervanaSystems/nlp-architect', 'https://github.com/koth/kcws', 'https://github.com/thisandagain/sentiment', 'https://github.com/endymecy/awesome-deeplearning-resources', 'https://github.com/aleju/papers', 'https://github.com/baidu/Familia', 'https://github.com/pytorch/text']
# Github_starlist [17408, 16941, 14047, 14042, 13947, 11439, 9771, 9592, 8786, 8756, 8696, 7974, 7444, 6711, 6702, 6435, 6392, 5934, 5077, 4996, 4965, 4767, 4375, 4074, 3813, 3570, 3510, 3495, 3269, 3107, 3037, 3024, 2922, 2879, 2826, 2683, 2612, 2320, 2288, 2235, 2126, 2054, 2037, 2020, 2008, 2004, 1952, 1898, 1860, 1813]
# 42.69986653327942

# %%
from bs4 import BeautifulSoup, SoupStrainer


parse_only = SoupStrainer("table", class_="hfs_overview")
soup = BeautifulSoup(br.response(), 'lxml', from_encoding="utf-8", parse_only=parse_only)

trs = soup.select('tr')

# %%
from bs4 import BeautifulSoup, SoupStrainer
import time
start_time = time.time()

req = Request('https://medium.com/search?q=nlp', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
soup = BeautifulSoup(webpage)
trs = soup.select('a')
end_time = time.time()
print(end_time-start_time)
# Out:
# 0.6410355567932129

# %%
trs

# %%
from bs4 import BeautifulSoup, SoupStrainer
import time
start_time = time.time()

req = Request('https://medium.com/search?q=nlp', headers={'User-Agent': 'Mozilla/5.0'})
webpage = urlopen(req).read()
parse_only = SoupStrainer( 'a', href=True)
soup = BeautifulSoup(webpage, parse_only=parse_only)

end_time = time.time()
print(end_time-start_time)
# Out:
# 0.5815095901489258

# %%
parse_only

# %%
soup = BeautifulSoup(test.text, parse_only=SoupStrainer('a', href=True))
for link in soup.find_all('a'):
    print link
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:166: UserWarning: The "parseOnlyThese" argument to the BeautifulSoup constructor has been renamed to "parse_only."
#   'has been renamed to "%s."' % (old_name, new_name))

# %%
# !pip install pygithub
# Out:
# Collecting pygithub
#   Using cached https://files.pythonhosted.org/packages/13/66/5c510242526d162708ffc0c82fd5ba647886f07d7abcae8587adeec86411/PyGithub-1.43.8.tar.gz
# Collecting deprecated (from pygithub)
#   Using cached https://files.pythonhosted.org/packages/88/0e/9d5a1a8cd7130c49334cce7b8167ceda63d6a329c8ea65b626116bc9e9e6/Deprecated-1.2.6-py2.py3-none-any.whl
# Collecting pyjwt (from pygithub)
#   Using cached https://files.pythonhosted.org/packages/87/8b/6a9f14b5f781697e51259d81657e6048fd31a113229cf346880bb7545565/PyJWT-1.7.1-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.6/dist-packages (from pygithub) (2.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.6/dist-packages (from deprecated->pygithub) (1.11.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->pygithub) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->pygithub) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->pygithub) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.14.0->pygithub) (2.8)
# Building wheels for collected packages: pygithub
#   Building wheel for pygithub (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/ba/9a/c3/d8a3dd0f2574b8fd4c43fea45385773c3bcbb1cae80d05f9ed
# Successfully built pygithub
# Installing collected packages: deprecated, pyjwt, pygithub
# Successfully installed deprecated-1.2.6 pygithub-1.43.8 pyjwt-1.7.1

# %%
from oauth2client.tools import argparser
from urllib.request import Request, urlopen
from urllib.parse import quote
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from github import Github  
import time
start_time = time.time()

g = Github("01f85a96bbfef290b6dba07a32e2e88afcd41e9c")


class Test:

  def med_links(self,x):
    self.x=x
    links = []
    for data in x:
      for a in data.find_all('a'):
          links.append(a.get('href')) 
    return (links)

  def clapcount(self,z):
    clapcount = []
    self.z=z 
    for node in z:
        clapcount.append(''.join(node.findAll(text=True)))
    return (clapcount)

  def med_titles(self,k):
    self.k=k
    titles = []
    for node in k:
        titles.append(''.join(node.findAll(text=True)))
    return (titles)
  
  def videotitle(self,vids):                         # youtube
    self.vids = vids
    videotitle=[]
    for v in vids:
        tmp =  v['title']
        videotitle.append(tmp)
    return videotitle
  
  def videourl(self,vids):
    self.vids = vids
    videourl=[]
    for v in vids:
        tmp = 'https://www.youtube.com' + v['href']
        videourl.append(tmp)
    return videourl
  
  def chname(self,xy):
    self.xy = xy
    chname1=[]
    for v in xy:
        tmp = v.find('a',attrs={'class':'yt-uix-sessionlink'}).text
        chname1.append(tmp)
    # chname = chname[1:]
    return chname1
  
  
    
      
  # Code with Papers functions
  def cop_desc(self,a):
    self.a = a
    desc = []
    for i in a:
      desc.append(i.find('p',attrs={'class':'item-strip-abstract'}).text)
    return desc
  
  def cop_codelinks(self,b):
    code = []
    github_code = []
    self.b = b
    
    for i in b:
      code.append( i.find('a',attrs={'class':'badge badge-dark'})['href'])

    base_url = 'https://paperswithcode.com'

    for i in range(len(code)):
      github_code.append('https://paperswithcode.com{}'.format(code[i]))
    return github_code
  
  def cop_titles(self,c):
    titles = []
    self.c = c
    for node in c:
        titles.append(''.join(node.findAll(text=True)))
    titles1 = titles[1:] # Because of the first content is coming as a str "Search Result"
    return titles1
  
  def html_urls(self,repos12):
    self.repos12 = repos12

    html_urls = []
    for i in repos12:
      html_urls.append(i.html_url)
    return html_urls

  def starslist(self,repos_name):
    self.repos_name = repos_name
    starslist1 = []
    for i in range(len(repos_name)):
          starslist = g.get_repo(repos_name[i])
          starslist1.append(starslist.stargazers_count)
    return starslist1


class Sol:
  ob=Test()
  user = str(input("Enter the Keyword:"))
  print(user)
  qstr = quote(str(user))#%20
  req = Request('https://medium.com/search?q={0}'.format(qstr), headers={'User-Agent': 'Mozilla/5.0'})
  webpage = urlopen(req).read()
  soup = BeautifulSoup(webpage)
  
  ## for code with papers
  qstr1  = quote_plus(user)#+
  req1 = Request('https://paperswithcode.com/search?q={0}'.format(qstr1), headers={'User-Agent': 'Mozilla/5.0'})
  webpage1 = urlopen(req1).read()
  soup1 = BeautifulSoup(webpage1)
  
  ## for Youtube
  qstr2  = quote_plus(user)
  req2 = Request("https://m.youtube.com/results?search_query={0}".format(qstr2), headers={'User-Agent': 'Mozilla/5.0'})
  webpage2 = urlopen(req2).read()
  soup2 = BeautifulSoup(webpage2)
  
  
  ## Github 
  repositories = g.search_repositories(query='topic:{0}'.format(user)) #need to solve for break iteraton
  
  try:
    repos =[]
    for repo in repositories:
        repos.append(repo.full_name)
    repos_name = repos[0:50]
  except Exception as ex:
    repos_name = repos[0:50]
     
  try:
    repos1 = []
    for repo in repositories:
        repos1.append(repo)
    repos12 = repos1[0:50]
  except Exception as ex:
    repos12 = repos1[0:50]
  
  y=soup.find_all('div',attrs= {'class':'postArticle-content'})
  x1=soup.findAll('span',attrs={'class':'u-relative u-background js-actionMultirecommendCount u-marginLeft5'})
  x2=soup.findAll('div',attrs={'class':'section-inner sectionLayout--insetColumn'})
  
  xy = soup2.findAll("div", "yt-lockup-byline")
  xy = xy[0:18]
  vids = soup2.findAll('a',attrs={'class':'yt-uix-tile-link'})
 
  res=ob.med_links(y)
  res1=ob.clapcount(x1)
  res2=ob.med_titles(x2)
 
  you1 = ob.videotitle(vids)
  you2 = ob.videourl(vids)
  you3 = ob.chname(xy)
  
  cop_desc = soup1.findAll('div',attrs={'class':'col-lg-9 item-content'})
  cop_codelinks =soup1.findAll('div',attrs={'class':'entity'})
  cop_titles = soup1.findAll('h1')
  
  cop1 = ob.cop_desc(cop_desc)
  cop2 = ob.cop_codelinks(cop_codelinks)
  cop3 = ob.cop_titles(cop_titles)
  
  a = ob.html_urls(repos12)
  b = ob.starslist(repos_name)
  
  print("\n######################################################")
  print("\nMedium-website contents")
  print("\nFound {0} contents".format(len(res2)))
  print("\nMedium_titles",res2)
  print("Medium_clapcount",res1)
  print("Medium_links",res)
  print("\n######################################################")
  print("\nYoutube contents")
  print("\nFound {0} contents".format(len(you1)))
  print("\nYoutube_titles",you1)
  print("Youtube_links",you2)
  print("Youtube_ch_titles",you3)
  print("\n######################################################")
  print("\nCode with Papers contents")
  print("\nFound {0} contents".format(len(cop3)))
  print("\nCode with Papers_titles",cop3)
  print("Code with Papers_desc",cop1)
  print("Code with Papers_codelinks",cop2)
  print("\n######################################################")
  print("\nGithub contents")
  print("\nFound {0} contents".format(len(repos_name)))
  print("\nGithub_repos_name",repos_name)
  print("Github_links",a)
  print("Github_starlist",b)
  end_time = time.time()
  print(end_time - start_time)
# Out:
# Enter the Keyword:nlp
# nlp
#
# ######################################################
#
# Medium-website contents
#
# Found 10 contents
#
# Medium_titles ['How to solve 90% of NLP problems: a step-by-step guideUsing Machine Learning to understand and…', 'Over 150 of the Best Machine Learning, NLP, and Python Tutorials I’ve\xa0FoundBy popular demand, I’ve updated this article with the latest tutorials from the past 12 months. Check it out\xa0here', 'Machine Learning, NLP: Text Classification using scikit-learn, python and\xa0NLTK.', 'Over 200 of the Best Machine Learning, NLP, and Python Tutorials\u200a-\u200a2018\xa0EditionThere are dozens\xa0of…', 'Ultimate Guide to Leveraging NLP & Machine Learning for your\xa0ChatbotCode Snippets and Github Included', 'NLP\u200a—\u200aBuilding a Question Answering modelDoing cool things with data!', 'BERT Explained: State of the art language model for\xa0NLP', 'Learning Machine Learning and NLP from 187 Quora QuestionsIf you like this article, check out another by Robbie:My Curated List of AI and Machine Learning Resources', 'Lessons Learned from Applying Deep Learning for NLP Without Big\xa0Data', 'How to get started in\xa0NLPSomewhere I read that if you ever have to answer the same question twice, it’s probably a good idea to turn it…']
# Medium_clapcount ['18K', '9.7K', '5.3K', '4.4K', '2.6K', '3.1K', '2.7K', '1.4K', '2.2K', '1.7K']
# Medium_links ['https://blog.insightdatascience.com/how-to-solve-90-of-nlp-problems-a-step-by-step-guide-fda605278e4e?source=search_post---------0', 'https://medium.com/machine-learning-in-practice/over-150-of-the-best-machine-learning-nlp-and-python-tutorials-ive-found-ffce2939bd78?source=search_post---------1', 'https://towardsdatascience.com/machine-learning-nlp-text-classification-using-scikit-learn-python-and-nltk-c52b92a7c73a?source=search_post---------2', 'https://medium.com/machine-learning-in-practice/over-200-of-the-best-machine-learning-nlp-and-python-tutorials-2018-edition-dd8cf53cb7dc?source=search_post---------3', 'https://chatbotslife.com/ultimate-guide-to-leveraging-nlp-machine-learning-for-you-chatbot-531ff2dd870c?source=search_post---------4', 'https://towardsdatascience.com/nlp-building-a-question-answering-model-ed0529a68c54?source=search_post---------5', 'https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270?source=search_post---------6', 'https://medium.com/machine-learning-in-practice/learning-machine-learning-and-nlp-from-185-quora-questions-cebe42e47da8?source=search_post---------7', 'https://towardsdatascience.com/lessons-learned-from-applying-deep-learning-for-nlp-without-big-data-d470db4f27bf?source=search_post---------8', 'https://towardsdatascience.com/how-to-get-started-in-nlp-6a62aa4eaeff?source=search_post---------9']
#
# ######################################################
#
# Youtube contents
#
# Found 21 contents
#
# Youtube_titles ['Faster than Hypnosis', 'NLP Training & Techniques: How To Use Neuro Linguistic Programming To Change Your Life', 'Natural Language Processing In 10 Minutes | NLP Tutorial For Beginners | NLP Training | Edureka', '3 NLP Techniques You Must Know', 'What is NLP & How Does It Work?  Neuro Linguistic Programming Basics', 'Richard Bandler (co-creator of NLP) Overcoming bad memories. LIVE demo.', 'Back to Basics; NLP Fundamentals', 'Training NLP with Tony Robbins', 'Neuro Linguistic Programming | Ram Verma | TEDxFORESchool', 'How to lose weight using NLP', 'FREE NLP Training - Live Seminar with Demonstrations', 'Swish Pattern - NLP Techniques', 'What is NLP? How can it help me?', 'NLP Techniques: One Simple Phrase To Overcome Resistance', 'Natural Language Processing (NLP) & Text Mining Tutorial Using NLTK | NLP Training | Edureka', 'NLP TRAINING: How To Program Your Subconscious Mind To Use The Law of Attraction', 'NLP LECTURE: SPEED ATTRACTION- How To Make Someone Love You In 20 Minutes Or Less', 'The master of nlp watch it', 'Discover Your Love Strategy | NLP Strategy - Conversational Seminar with Demonstration', 'Neuro Linguistic Programming Techniques You Can Use Instantly', 'Program Your Mind Like a Computer | Dr Richard Bandler (CO-Founder of NLP)']
# Youtube_links ['https://www.youtube.comhttps://www.googleadservices.com/pagead/aclk?sa=L&ai=CpGfj93s9XY2DMIvIsgfQzarQDPmgzLFT8rSelqABwI23ARABIABgyQaCARdjYS1wdWItNjIxOTgxMTc0NzA0OTM3MaABlPSV5wOoAwSqBMUBT9A1k6ABMCSn0MBZ-tvJDaufisZThH3aSaZ-Q9YdQnNBJ2aseCgWx0e06pnIh9ssqSiRb8NOz2V5w0Bf6q8sD5dRAnVYAP1ogsMdvlnAkOuAO4GsLIGIrRJAkLgJvU3ulsssZN_GBQ1rbey93O3FSbVXTM6xf89nX0kwiNXqdjRRi9yeUkq6P651L_Z4e8kRsP_maqoexDOouzdG51EmhcQthznVmgeeQJNN8iDabwr1ue8Zz2Yhyc53Ijn44_7tFz0bu62IBdLP6FeSBQwIEjDn3-Skza7G3j6SBQcIE3ik1NQZkgUECAMQAqAGGtgGBYAH1IvqGJAHBKgHqNIbqAfZyxuoB8_MG6gHtgeoB-DPG6gH6dQbqAe21xuoB4zNG6gH1c4bqAeBxhuoB5jOG6gHq8UbqAfezhuoB7_VG5IIC1ByMFpkTlNaTC1j0ggFCIBBEAGxCWxDsZ61s3q0yAkXuBPoAbAUA8AVAdgVAQ&num=1&cid=CAASFeRotFzg1_m12v3Z8zXBUKvn8vDhpA&sig=AOD64_03tn1Qnnza8uZxT_yaWvxE55zC8g&adurl=http://www.youtube.com/watch%3Fv%3DPr0ZdNSZL-c&ctype=21&video_id=Pr0ZdNSZL-c&client=ca-pub-6219811747049371', 'https://www.youtube.com/watch?v=5ecLYP3FE6g', 'https://www.youtube.com/watch?v=5ctbvkAMQO4', 'https://www.youtube.com/watch?v=DhB9fE-TQow', 'https://www.youtube.com/watch?v=MQiMFs2SIFk', 'https://www.youtube.com/watch?v=Z_RQxt0Wcgk', 'https://www.youtube.com/watch?v=t5eSo4mgQ4g', 'https://www.youtube.com/watch?v=ANY8-_kqCZQ', 'https://www.youtube.com/watch?v=syvKeNKww_Y', 'https://www.youtube.com/watch?v=NghY51I6RA4', 'https://www.youtube.com/watch?v=Gfp5absKF94', 'https://www.youtube.com/watch?v=DyRfpod2fxw', 'https://www.youtube.com/watch?v=EGe1deya3uU', 'https://www.youtube.com/watch?v=7_Xh4MPCGRk', 'https://www.youtube.com/watch?v=05ONoGfmKvA', 'https://www.youtube.com/watch?v=IvO8ZsQYUK0', 'https://www.youtube.com/watch?v=ui7h8CTSD_8', 'https://www.youtube.com/watch?v=qcnjuJliu-k', 'https://www.youtube.com/watch?v=TwnQQRVd-H8', 'https://www.youtube.com/watch?v=MIl3WGKVBn4', 'https://www.youtube.com/watch?v=zsyZFeccSmo']
# Youtube_ch_titles ['MindMaster.TV', 'Project Life Mastery', 'edureka!', 'Life Mastery Gym', 'Bay Area NLP And Hypnosis', 'NLPLife', 'NLPAcademy', 'coachingnlptraining', 'TEDx Talks', 'Anthony Beardsell', 'IntraAwareness', 'Anthony Beardsell', 'Anthony Beardsell', 'Life Mastery Gym', 'edureka!', 'David Snyder', 'David Snyder', 'Stefan Lux']
#
# ######################################################
#
# Code with Papers contents
#
# Found 10 contents
#
# Code with Papers_titles ['FLAIR: An Easy-to-Use Framework for State-of-the-Art NLP', 'NeuronBlocks: Building Your NLP DNN Models Like Playing Lego', 'Mixed-Precision Training for NLP and Speech Recognition with OpenSeq2Seq', 'BERT Rediscovers the Classical NLP Pipeline', 'CogCompNLP: Your Swiss Army Knife for NLP', 'Probing What Different NLP Tasks Teach Machines about Function Word Comprehension', 'BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding', 'XLNet: Generalized Autoregressive Pretraining for Language Understanding', 'A Dataset of Peer Reviews (PeerRead): Collection, Insights and NLP Applications', 'AllenNLP: A Deep Semantic Natural Language Processing Platform']
# Code with Papers_desc ['We present FLAIR, an NLP framework designed to facilitate training and distribution of state-of-the-art sequence labeling, text classification and language models.', 'Deep Neural Networks (DNN) have been widely employed in industry to address various Natural Language Processing (NLP) tasks.', 'We present OpenSeq2Seq - a TensorFlow-based toolkit for training sequence-to-sequence models that features distributed and mixed-precision training.', 'Pre-trained text encoders have rapidly advanced the state of the art on many NLP tasks.', '', 'We introduce a set of nine challenge tasks that test for the understanding of function words.', 'We introduce a new language representation model called BERT, which stands for Bidirectional Encoder Representations from Transformers.', 'With the capability of modeling bidirectional contexts, denoising autoencoding based pretraining like BERT achieves better performance than pretraining approaches based on autoregressive language modeling.', 'In the first task, we show that simple models can predict whether a paper is accepted with up to 21% error reduction compared to the majority baseline.', 'This paper describes AllenNLP, a platform for research on deep learning methods in natural language understanding.']
# Code with Papers_codelinks ['https://paperswithcode.com/paper/flair-an-easy-to-use-framework-for-state-of#code', 'https://paperswithcode.com/paper/neuronblocks-building-your-nlp-dnn-models#code', 'https://paperswithcode.com/paper/mixed-precision-training-for-nlp-and-speech#code', 'https://paperswithcode.com/paper/bert-rediscovers-the-classical-nlp-pipeline#code', 'https://paperswithcode.com/paper/cogcompnlp-your-swiss-army-knife-for-nlp#code', 'https://paperswithcode.com/paper/probing-what-different-nlp-tasks-teach#code', 'https://paperswithcode.com/paper/bert-pre-training-of-deep-bidirectional#code', 'https://paperswithcode.com/paper/xlnet-generalized-autoregressive-pretraining#code', 'https://paperswithcode.com/paper/a-dataset-of-peer-reviews-peerread-collection#code', 'https://paperswithcode.com/paper/allennlp-a-deep-semantic-natural-language#code']
#
# ######################################################
#
# Github contents
#
# Found 50 contents
#
# Github_repos_name ['apachecn/AiLearning', 'google-research/bert', 'hankcs/HanLP', 'oxford-cs-deepnlp-2017/lectures', 'explosion/spaCy', 'virgili0/Virgilio', 'huggingface/pytorch-transformers', 'RaRe-Technologies/gensim', 'spencermountain/compromise', 'chiphuyen/stanford-tensorflow-tutorials', 'keon/awesome-nlp', 'nltk/nltk', 'bharathgs/Awesome-pytorch-list', 'zalandoresearch/flair', 'allenai/allennlp', 'stanfordnlp/CoreNLP', 'sloria/TextBlob', 'RasaHQ/rasa', 'NLPchina/ansj_seg', 'nfmcclure/tensorflow_cookbook', 'brightmart/text_classification', 'hanxiao/bert-as-service', 'crownpku/Awesome-Chinese-NLP', 'zihangdai/xlnet', 'vi3k6i5/flashtext', 'graykode/nlp-tutorial', 'MycroftAI/mycroft-core', 'spro/practical-pytorch', 'deepmipt/DeepPavlov', 'kelaberetiv/TagUI', 'brightmart/nlp_chinese_corpus', 'wooorm/franc', 'jadore801120/attention-is-all-you-need-pytorch', 'axa-group/nlp.js', 'snipsco/snips-nlu', 'codertimo/BERT-pytorch', 'Kyubyong/nlp_tasks', 'openvenues/libpostal', 'RasaHQ/rasa_core', 'stanfordnlp/stanfordnlp', 'HIT-SCIR/ltp', 'DSKSD/DeepNLP-models-Pytorch', 'jdkato/prose', 'NervanaSystems/nlp-architect', 'koth/kcws', 'thisandagain/sentiment', 'endymecy/awesome-deeplearning-resources', 'aleju/papers', 'baidu/Familia', 'pytorch/text']
# Github_links ['https://github.com/apachecn/AiLearning', 'https://github.com/google-research/bert', 'https://github.com/hankcs/HanLP', 'https://github.com/oxford-cs-deepnlp-2017/lectures', 'https://github.com/explosion/spaCy', 'https://github.com/virgili0/Virgilio', 'https://github.com/huggingface/pytorch-transformers', 'https://github.com/RaRe-Technologies/gensim', 'https://github.com/spencermountain/compromise', 'https://github.com/chiphuyen/stanford-tensorflow-tutorials', 'https://github.com/keon/awesome-nlp', 'https://github.com/nltk/nltk', 'https://github.com/bharathgs/Awesome-pytorch-list', 'https://github.com/zalandoresearch/flair', 'https://github.com/allenai/allennlp', 'https://github.com/stanfordnlp/CoreNLP', 'https://github.com/sloria/TextBlob', 'https://github.com/RasaHQ/rasa', 'https://github.com/NLPchina/ansj_seg', 'https://github.com/nfmcclure/tensorflow_cookbook', 'https://github.com/brightmart/text_classification', 'https://github.com/hanxiao/bert-as-service', 'https://github.com/crownpku/Awesome-Chinese-NLP', 'https://github.com/zihangdai/xlnet', 'https://github.com/vi3k6i5/flashtext', 'https://github.com/graykode/nlp-tutorial', 'https://github.com/MycroftAI/mycroft-core', 'https://github.com/spro/practical-pytorch', 'https://github.com/deepmipt/DeepPavlov', 'https://github.com/kelaberetiv/TagUI', 'https://github.com/brightmart/nlp_chinese_corpus', 'https://github.com/wooorm/franc', 'https://github.com/jadore801120/attention-is-all-you-need-pytorch', 'https://github.com/axa-group/nlp.js', 'https://github.com/snipsco/snips-nlu', 'https://github.com/codertimo/BERT-pytorch', 'https://github.com/Kyubyong/nlp_tasks', 'https://github.com/openvenues/libpostal', 'https://github.com/RasaHQ/rasa_core', 'https://github.com/stanfordnlp/stanfordnlp', 'https://github.com/HIT-SCIR/ltp', 'https://github.com/DSKSD/DeepNLP-models-Pytorch', 'https://github.com/jdkato/prose', 'https://github.com/NervanaSystems/nlp-architect', 'https://github.com/koth/kcws', 'https://github.com/thisandagain/sentiment', 'https://github.com/endymecy/awesome-deeplearning-resources', 'https://github.com/aleju/papers', 'https://github.com/baidu/Familia', 'https://github.com/pytorch/text']
# Github_starlist [17510, 17006, 14078, 14050, 13975, 11455, 9901, 9607, 8790, 8758, 8704, 7989, 7457, 6740, 6719, 6443, 6401, 5962, 5078, 5001, 4975, 4783, 4387, 4112, 3817, 3598, 3511, 3501, 3282, 3115, 3049, 3023, 2934, 2888, 2835, 2687, 2612, 2327, 2287, 2259, 2127, 2059, 2039, 2024, 2007, 2005, 1954, 1900, 1862, 1816]
# 42.44956636428833

# %%
from oauth2client.tools import argparser
from urllib.request import Request, urlopen
from urllib.parse import quote
from urllib.parse import quote_plus
from bs4 import BeautifulSoup
from github import Github  
import time
start_time = time.time()


class Test:

  def med_links(self,x):
    self.x=x
    links = []
    for data in x:
      for a in data.find_all('a'):
          links.append(a.get('href')) 
    return (links)

  def clapcount(self,z):
    clapcount = []
    self.z=z 
    for node in z:
        clapcount.append(''.join(node.findAll(text=True)))
    return (clapcount)

  def med_titles(self,k):
    self.k=k
    titles = []
    for node in k:
        titles.append(''.join(node.findAll(text=True)))
    return (titles)
  
  def videotitle(self,vids):                         # youtube
    self.vids = vids
    videotitle=[]
    for v in vids:
        tmp =  v['title']
        videotitle.append(tmp)
    return videotitle
  
  def videourl(self,vids):
    self.vids = vids
    videourl=[]
    for v in vids:
        tmp = 'https://www.youtube.com' + v['href']
        videourl.append(tmp)
    return videourl
  
  def chname(self,xy):
    self.xy = xy
    chname1=[]
    for v in xy:
        tmp = v.find('a',attrs={'class':'yt-uix-sessionlink'}).text
        chname1.append(tmp)
    # chname = chname[1:]
    return chname1
  
  
    
      
  # Code with Papers functions
  def cop_desc(self,a):
    self.a = a
    desc = []
    for i in a:
      desc.append(i.find('p',attrs={'class':'item-strip-abstract'}).text)
    return desc
  
  def cop_codelinks(self,b):
    code = []
    github_code = []
    self.b = b
    
    for i in b:
      code.append( i.find('a',attrs={'class':'badge badge-dark'})['href'])

    for i in range(len(code)):
      github_code.append('https://paperswithcode.com{}'.format(code[i]))
    return github_code
  
  def cop_titles(self,c):
    titles = []
    self.c = c
    for node in c:
        titles.append(''.join(node.findAll(text=True)))
    titles1 = titles[1:] # Because of the first content is coming as a str "Search Result"
    return titles1
  
#   def html_urls(self,repos12):
#     self.repos12 = repos12

#     html_urls = []
#     for i in repos12:
#       html_urls.append(i.html_url)
#     return html_urls

#   def starslist(self,repos_name):
#     self.repos_name = repos_name
#     starslist1 = []
#     for i in range(len(repos_name)):
#           starslist = g.get_repo(repos_name[i])
#           starslist1.append(starslist.stargazers_count)
#     return starslist1

  def git_titles(self,x):
      self.x = x
      titles = []
      for node in x:
            titles.append(' '.join(node.findAll(text=True)))
      return titles
    
  def git_links(self,x):
    self.x = x
    links = []
    for a in x :
        links.append('https://github.com{}'.format(a['href']))
    return links
  
  def git_stars(self,x):
    self.x = x
    stars = []

    for node in x:
        stars.append(''.join(node.findAll(text=True)))
    stars1 = [x.strip('  \n') for x in stars]
    
    return stars1


class Sol:
  ob=Test()
  user = str(input("Enter the Keyword:"))
  print(user)
  qstr = quote(str(user))#%20
  req = Request('https://medium.com/search?q={0}'.format(qstr), headers={'User-Agent': 'Mozilla/5.0'})
  webpage = urlopen(req).read()
  soup = BeautifulSoup(webpage)
  
  ## for code with papers
  qstr1  = quote_plus(user)#+
  req1 = Request('https://paperswithcode.com/search?q={0}'.format(qstr1), headers={'User-Agent': 'Mozilla/5.0'})
  req1.add_header('Accept-Encoding','utf-8')
  webpage1 = urlopen(req1).read()
  soup1 = BeautifulSoup(webpage1.decode('utf-8','ignore'))
  
  ## for Youtube
  qstr2  = quote_plus(user)
  req2 = Request("https://m.youtube.com/results?search_query={0}".format(qstr2), headers={'User-Agent': 'Mozilla/5.0'})
  webpage2 = urlopen(req2).read()
  soup2 = BeautifulSoup(webpage2)
  
  
  ## for  Github 
  qstr3 = quote_plus(user)
  req3 = Request('https://github.com/search?q={0}'.format(qstr3), headers={'User-Agent': 'Mozilla/5.0'})
  webpage3 = urlopen(req3).read()
  soup3 = BeautifulSoup(webpage3)
#   repositories = g.search_repositories(query='topic:{0}'.format(user)) #need to solve for break iteraton
  
#   try:
#     repos =[]
#     for repo in repositories:
#         repos.append(repo.full_name)
#     repos_name = repos[0:50]
#   except Exception as ex:
#     repos_name = repos[0:50]
     
#   try:
#     repos1 = []
#     for repo in repositories:
#         repos1.append(repo)
#     repos12 = repos1[0:50]
#   except Exception as ex:
#     repos12 = repos1[0:50]
  x3 = soup3.find_all('a',attrs= {'class':'v-align-middle'})
  y3 = soup3.find_all('a',attrs= {'class':'v-align-middle'},href = True)
  z3 = soup3.findAll('div',attrs= {'class':'pl-2 pl-md-0 text-right flex-auto min-width-0'})
  
  
  
  
  y=soup.find_all('div',attrs= {'class':'postArticle-content'})
  x1=soup.findAll('span',attrs={'class':'u-relative u-background js-actionMultirecommendCount u-marginLeft5'})
  x2=soup.findAll('div',attrs={'class':'section-inner sectionLayout--insetColumn'})
  
  xy = soup2.findAll("div", "yt-lockup-byline")
  xy = xy[0:18]
  vids = soup2.findAll('a',attrs={'class':'yt-uix-tile-link'})
 
  res=ob.med_links(y)
  res1=ob.clapcount(x1)
  res2=ob.med_titles(x2)
 
  you1 = ob.videotitle(vids)
  you2 = ob.videourl(vids)
  you3 = ob.chname(xy)
  
  cop_desc = soup1.findAll('div',attrs={'class':'col-lg-9 item-content'})
  cop_codelinks =soup1.findAll('div',attrs={'class':'entity'})
  cop_titles = soup1.findAll('h1')
  
  cop1 = ob.cop_desc(cop_desc)
  cop2 = ob.cop_codelinks(cop_codelinks)
  cop3 = ob.cop_titles(cop_titles)
  
#   a = ob.html_urls(repos12)
#   b = ob.starslist(repos_name)

  git_titles = ob.git_titles(x3)
  git_links = ob.git_links(y3)
  git_stars = ob.git_stars(z3)
  
  print("\n######################################################")
  print("\nMedium-website contents")
  print("\nFound {0} contents".format(len(res2)))
  print("\nMedium_titles",res2)
  print("Medium_clapcount",res1)
  print("Medium_links",res)
  print("\n######################################################")
  print("\nYoutube contents")
  print("\nFound {0} contents".format(len(you1)))
  print("\nYoutube_titles",you1)
  print("Youtube_links",you2)
  print("Youtube_ch_titles",you3)
  print("\n######################################################")
  print("\nCode with Papers contents")
  print("\nFound {0} contents".format(len(cop3)))
  print("\nCode with Papers_titles",cop3)
  print("Code with Papers_desc",cop1)
  print("Code with Papers_codelinks",cop2)
  print("\n######################################################")
  print("\nGithub contents")
  print("\nFound {0} contents".format(len(git_titles)))
  print("\nGithub_repos_name",git_titles)
  print("Github_links",git_links)
  print("Github_starlist",git_stars)
  end_time = time.time()
  print(end_time - start_time)
# Out:
# Enter the Keyword:nltk
# nltk
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-8b6ad38f1bbc> in <module>()
#     130
#     131
# --> 132 class Sol:
#     133   ob=Test()
#     134   user = str(input("Enter the Keyword:"))
#
# <ipython-input-4-8b6ad38f1bbc> in Sol()
#     203
#     204   cop1 = ob.cop_desc(cop_desc)
# --> 205   cop2 = ob.cop_codelinks(cop_codelinks)
#     206   cop3 = ob.cop_titles(cop_titles)
#     207
#
# <ipython-input-4-8b6ad38f1bbc> in cop_codelinks(self, b)
#      75
#      76     for i in b:
# ---> 77       code.append( i.find('a',attrs={'class':'badge badge-dark'})['href'])
#      78
#      79     for i in range(len(code)):
#
# TypeError: 'NoneType' object is not subscriptable

# %%
n

# %%
import requests
from bs4 import BeautifulSoup

headers = {'Accept-Language': 'en-US,en'}

page = requests.get('https://medium.com/search?q=nltk', headers=headers)
soup = BeautifulSoup(page.content, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html xmlns:cc="http://creativecommons.org/ns#"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# medium-com: http://ogp.me/ns/fb/medium-com#"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1.0, viewport-fit=contain" name="viewport"/><title>Search and find – Medium</title><link href="https://medium.com/search" rel="canonical"/><meta content="Search and find – Medium" name="title"/><meta content="unsafe-url" name="referrer"/><meta content="Search on Medium and find the most popular voices writing about topics that matter." name="description"/><meta content="#000000" name="theme-color"/><meta content="Search and find – Medium" property="og:title"/><meta content="Search and find – Medium" property="twitter:title"/><meta content="https://medium.com/search" property="og:url"/><meta content="542599432471018" property="fb:app_id"/><meta content="Search on Medium and find the most popular voices writing about topics that matter." property="og:description"/><meta content="Search on Medium and find the most popular voices writing about topics that matter." name="twitter:description"/><meta content="" name="twitter:image:src"/><meta content="@Medium" name="twitter:site"/><meta content="Medium" property="og:site_name"/><meta content="Medium" name="twitter:app:name:iphone"/><meta content="828256236" name="twitter:app:id:iphone"/><meta content="medium://search" name="twitter:app:url:iphone"/><meta content="Medium" property="al:ios:app_name"/><meta content="828256236" property="al:ios:app_store_id"/><meta content="com.medium.reader" property="al:android:package"/><meta content="Medium" property="al:android:app_name"/><meta content="medium://search" property="al:ios:url"/><meta content="medium://search" property="al:android:url"/><meta content="https://medium.com/search" property="al:web:url"/><link href="/osd.xml" rel="search" title="Medium" type="application/opensearchdescription+xml"/><link href="android-app://com.medium.reader/https/medium.com/search" rel="alternate"/><meta content="https://medium.com/search" name="parsely-link"/><link href="https://cdn-static-1.medium.com/_/fp/css/main-branding-base.DUpq82k2YI6OvEW6173IfA.css" rel="stylesheet"/><script>!function(n,e){var t,o,i,c=[],f={passive:!0,capture:!0},r=new Date,a="pointerup",u="pointercancel";function p(n,c){t||(t=c,o=n,i=new Date,w(e),s())}function s(){o>=0&&o<i-r&&(c.forEach(function(n){n(o,t)}),c=[])}function l(t){if(t.cancelable){var o=(t.timeStamp>1e12?new Date:performance.now())-t.timeStamp;"pointerdown"==t.type?function(t,o){function i(){p(t,o),r()}function c(){r()}function r(){e(a,i,f),e(u,c,f)}n(a,i,f),n(u,c,f)}(o,t):p(o,t)}}function w(n){["click","mousedown","keydown","touchstart","pointerdown"].forEach(function(e){n(e,l,f)})}w(n),self.perfMetrics=self.perfMetrics||{},self.perfMetrics.onFirstInputDelay=function(n){c.push(n),s()}}(addEventListener,removeEventListener);</script><script>if (window.top !== window.self) window.top.location = window.self.location.href;var OB_startTime = new Date().getTime(); var OB_loadErrors = []; function _onerror(e) { OB_loadErrors.push(e) }; if (document.addEventListener) document.addEventListener("error", _onerror, true); else if (document.attachEvent) document.attachEvent("onerror", _onerror); function _asyncScript(u) {var d = document, f = d.getElementsByTagName("script")[0], s = d.createElement("script"); s.type = "text/javascript"; s.async = true; s.src = u; f.parentNode.insertBefore(s, f);}function _asyncStyles(u) {var d = document, f = d.getElementsByTagName("script")[0], s = d.createElement("link"); s.rel = "stylesheet"; s.href = u; f.parentNode.insertBefore(s, f); return s}(new Image()).src = "/_/stat?event=pixel.load&origin=" + encodeURIComponent(location.origin);</script><script>window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date; ga("create", "UA-24232453-2", "auto", {"allowLinker": true, "legacyCookieDomain": window.loc ...
# window["obvInit"] = function (opt_embedded) {window["obvInit"]["embedded"] = opt_embedded; window["obvInit"]["ready"] = true;}
# // ]]></script><script>// <![CDATA[
# var GLOBALS = {"audioUrl":"https://d1fcbxp97j4nb2.cloudfront.net","baseUrl":"https://medium.com","buildLabel":"38189","currentUser":{"userId":"lo_Ni9kdeK0Gajt","isVerified":false,"subscriberEmail":"","hasPastMemberships":false,"isEnrolledInHightower":false,"isEligibleForHightower":false,"hightowerLastLockedAt":0,"isWriterProgramEnrolled":true,"isWriterProgramInvited":false,"isWriterProgramOptedOut":false,"writerProgramVersion":0,"writerProgramEnrolledAt":0,"friendLinkOnboarding":0,"hasAdditionalUnlocks":false,"hasApiAccess":false,"isQuarantined":false,"writerProgramDistributionSettingOptedIn":false},"currentUserHasUnverifiedEmail":false,"isAuthenticated":false,"isCurrentUserVerified":false,"language":"en-us","miroUrl":"https://cdn-images-1.medium.com","moduleUrls":{"base":"https://cdn-static-1.medium.com/_/fp/gen-js/main-base.bundle.um-_om_Par5lcIvhZ4kBbA.js","common-async":"https://cdn-static-1.medium.com/_/fp/gen-js/main-common-async.bundle.BW9PYIgmoFU9VbxeqQIPBg.js","hightower":"https://cdn-static-1.medium.com/_/fp/gen-js/main-hightower.bundle.ky9_kjVbn7TTckP0aCkRSA.js","home-screens":"https://cdn-static-1.medium.com/_/fp/gen-js/main-home-screens.bundle.qWsk2-LY4but7t0tqpVLAQ.js","misc-screens":"https://cdn-static-1.medium.com/_/fp/gen-js/main-misc-screens.bundle.kVBc6gskcuksxLBxdUjQWg.js","notes":"https://cdn-static-1.medium.com/_/fp/gen-js/main-notes.bundle.hfRvimbN-1YY4U9c8fof5g.js","payments":"https://cdn-static-1.medium.com/_/fp/gen-js/main-payments.bundle.GJ7c0QSNwnIzGvFgyV8ckg.js","posters":"https://cdn-static-1.medium.com/_/fp/gen-js/main-posters.bundle.7YpIlB3G5gykEPfo8CWqfg.js","power-readers":"https://cdn-static-1.medium.com/_/fp/gen-js/main-power-readers.bundle.G9OxkRfHd91k8pt-2IE5VQ.js","pubs":"https://cdn-static-1.medium.com/_/fp/gen-js/main-pubs.bundle.KNao8JrRGdPMQYdUzexMng.js","stats":"https://cdn-static-1.medium.com/_/fp/gen-js/main-stats.bundle.TVQEiFTfPyemj8TcDbkaSQ.js"},"previewConfig":{"weightThreshold":1,"weightImageParagraph":0.51,"weightIframeParagraph":0.8,"weightTextParagraph":0.08,"weightEmptyParagraph":0,"weightP":0.003,"weightH":0.005,"weightBq":0.003,"minPTextLength":60,"truncateBoundaryChars":20,"detectTitle":true,"detectTitleLevThreshold":0.15},"productName":"Medium","supportsEdit":false,"termsUrl":"//medium.com/policy/9db0094a1e0f","textshotHost":"textshot.medium.com","transactionId":"1564315990738:41d70ec71b65","useragent":{"browser":"python requests","family":"","os":"","version":2.21,"supportsDesktopEdit":false,"supportsInteract":false,"supportsView":true,"isMobile":false,"isTablet":false,"isNative":false,"supportsFileAPI":false,"isTier1":false,"clientVersion":"","unknownParagraphsBad":false,"clientChannel":"","supportsRealScrollEvents":false,"supportsVhUnits":false,"ruinsViewportSections":false,"supportsHtml5Video":false,"supportsMagicUnderlines":false,"isWebView":false,"isFacebookWebView":false,"supportsProgressiveMedia":false,"supportsPromotedPosts":true,"isBot":false,"isNativeIphone":false,"supportsCssVariables":false,"supportsVideoSections":true,"emojiSupportLevel":1,"isSearchBot":false,"isSyndicationBot":false,"isNativeAndroid":false,"isNativeIos":false,"isSeoBot":false,"supportsScrollableMetabar":false},"variants":{"allow_access":true,"allow_signup":true,"allow_test_auth":"disallow","signin_services":"twitter,facebook,google,email,google-fastidv,google-one-tap","signup_services":"twitter,facebook,google,email,google-fastidv,google-one-tap","google_sign_in_android":true,"reengagement_notification_duration":3,"browsable_stream_config_bucket":"curated-topics","enable_dedicated_series_tab_api_ios":true,"enable_post_import":true,"available_monthly_plan":"60e220181034","available_annual_plan":"2c754bcc2995","disable_ios_resume_reading_toast":true,"is_not_medium_subscriber":true,"glyph_font_set":"m2","enable_branding":true,"enable_branding_fonts":true,"max_premium_content_per_user_under_metering":3,"enable_automated_mission_control_triggers":true,"enable_lite_profile":true,"enable_market ...
# // ]]></script><script async="" charset="UTF-8" src="https://cdn-static-1.medium.com/_/fp/gen-js/main-base.bundle.um-_om_Par5lcIvhZ4kBbA.js"></script><script>// <![CDATA[
# window["obvInit"]({"posts":[{"id":"7c8c8215ac6e","versionId":"aca938cda8da","creatorId":"7053de462a28","creator":{"userId":"7053de462a28","name":"Parul Pandey","username":"parulnith","createdAt":1503199724429,"imageId":"1*-ooorT2_5GQSfQoVFxJHXw.jpeg","backgroundImageId":"","bio":"Data Science @H2O.ai | Linkedin: https://www.linkedin.com/in/parul-pandey-a5498975/","twitterScreenName":"pandeyparul","facebookAccountId":"","allowNotes":1,"mediumMemberAt":1535549659000,"isNsfw":false,"isWriterProgramEnrolled":true,"isQuarantined":false,"type":"User"},"homeCollection":{"id":"7219b4dc6c4c","name":"Analytics Vidhya","slug":"analytics-vidhya","tags":["MACHINE LEARNING","ARTIFICIAL INTELLIGENCE","DEEP LEARNING","DATA SCIENCE","PYTHON"],"creatorId":"c7c686fcd4b","description":"Analytics Vidhya is a community of Analytics and Data Science professionals. We are building the next-gen data science ecosystem https://www.analyticsvidhya.com","shortDescription":"Analytics Vidhya is a community of Analytics and Data…","image":{"imageId":"1*miCA9MEw8TjpXyR0xY1w-A.png","filter":"","backgroundSize":"","originalWidth":64,"originalHeight":64,"strategy":"resample","height":0,"width":0},"metadata":{"followerCount":10524,"activeAt":1564290902039},"virtuals":{"permissions":{"canPublish":false,"canPublishAll":false,"canRepublish":false,"canRemove":false,"canManageAll":false,"canSubmit":false,"canEditPosts":false,"canAddWriters":false,"canViewStats":false,"canSendNewsletter":false,"canViewLockedPosts":false,"canViewCloaked":false,"canEditOwnPosts":false,"canBeAssignedAuthor":false,"canEnrollInHightower":false,"canLockPostsForMediumMembers":false,"canLockOwnPostsForMediumMembers":false},"isSubscribed":false,"isNewsletterSubscribed":false,"isEnrolledInHightower":false,"isEligibleForHightower":false,"mediumNewsletterId":"","isSubscribedToMediumNewsletter":false},"logo":{"imageId":"1*cK8jYS5H7rDYhb0vZkW4NA.png","filter":"","backgroundSize":"","originalWidth":364,"originalHeight":90,"strategy":"resample","height":0,"width":0},"twitterUsername":"analyticsvidhya","facebookPageName":"analyticsvidhya","publicEmail":"medium@analyticsvidhya.com","sections":[{"type":2,"collectionHeaderMetadata":{"backgroundImage":{},"logoImage":{"id":"1*cK8jYS5H7rDYhb0vZkW4NA@2x.png","originalWidth":364,"originalHeight":90,"alt":"Analytics Vidhya"},"alignment":2,"layout":4}},{"type":1,"postListMetadata":{"source":3,"layout":4,"number":4,"postIds":["3273ad8d28de","2e38d8718d17","f06216c7200e","7ce63d5c1f3b"]}},{"type":1,"postListMetadata":{"source":2,"layout":4,"number":5,"postIds":[],"sectionHeader":"Popular Stories"}},{"type":1,"postListMetadata":{"source":1,"layout":4,"number":5,"postIds":[],"sectionHeader":"Latest Stories"}},{"type":1,"postListMetadata":{"source":4,"layout":4,"number":3,"postIds":[],"tagSlug":"Machine Learning","sectionHeader":"Machine Learning"}},{"type":1,"postListMetadata":{"source":4,"layout":4,"number":3,"postIds":[],"tagSlug":"Deep Learning","sectionHeader":"Deep Learning"}},{"type":1,"postListMetadata":{"source":4,"layout":4,"number":3,"postIds":[],"tagSlug":"Hackathons","sectionHeader":"Hackathons"}},{"type":1,"postListMetadata":{"source":4,"layout":4,"number":3,"postIds":[],"tagSlug":"Programming","sectionHeader":"Programming"}}],"favicon":{"imageId":"","filter":"","backgroundSize":"","originalWidth":0,"originalHeight":0,"strategy":"resample","height":0,"width":0},"colorPalette":{"defaultBackgroundSpectrum":{"colorPoints":[{"color":"#FF02B875","point":0},{"color":"#FF00AB6B","point":0.1},{"color":"#FF1C9963","point":0.2},{"color":"#FF092E20","point":1}],"backgroundColor":"#FFFFFFFF"},"highlightSpectrum":{"colorPoints":[{"color":"#FFFFFFFF","point":0},{"color":"#FFE9FDF0","point":0.1},{"color":"#FFE2FAEE","point":0.2},{"color":"#FFADFFCF","point":0.6},{"color":"#FF7DFFB3","point":1}],"backgroundColor":"#FFFFFFFF"}},"navItems":[{"type":6,"title":"About Us","url":"https://medium.com/analytics-vidhya/about"},{"type":1,"title":"Machine Learning","tagSlug":"mach ...
# // ]]></script><script>window.PARSELY = window.PARSELY || { autotrack: false }</script><script id="parsely-cfg" src="//d1z2jf7jlzjs58.cloudfront.net/keys/medium.com/p.js"></script><script type="text/javascript">(function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent".split(" "), 0); branch.init('key_live_ofxXr2qTrrU9NqURK8ZwEhknBxiI6KBm', {'no_journeys': true, 'disable_exit_animation': true, 'disable_entry_animation': true, 'tracking_disabled':  false }, function(err, data) {});</script></body></html>

# %% [markdown]
# ##testing

# %%
def searching():
 
  
  from oauth2client.tools import argparser
  from urllib.request import Request, urlopen
  from urllib.parse import quote
  from urllib.parse import quote_plus
  from bs4 import BeautifulSoup
  from github import Github  
  import time
  

  g = Github("01f85a96bbfef290b6dba07a32e2e88afcd41e9c")


  class Test:

    def med_links(self,x):
      self.x=x
      links = []
      for data in x:
        for a in data.find_all('a'):
            links.append(a.get('href')) 
      return (links)

    def clapcount(self,z):
      clapcount = []
      self.z=z 
      for node in z:
          clapcount.append(''.join(node.findAll(text=True)))
      return (clapcount)

    def med_titles(self,k):
      self.k=k
      titles = []
      for node in k:
          titles.append(''.join(node.findAll(text=True)))
      return (titles)

    def videotitle(self,vids):                         # youtube
      self.vids = vids
      videotitle=[]
      for v in vids:
          tmp =  v['title']
          videotitle.append(tmp)
      return videotitle

    def videourl(self,vids):
      self.vids = vids
      videourl=[]
      for v in vids:
          tmp = 'https://www.youtube.com' + v['href']
          videourl.append(tmp)
      return videourl

    def chname(self,xy):
      self.xy = xy
      chname1=[]
      for v in xy:
          tmp = v.find('a',attrs={'class':'yt-uix-sessionlink'}).text
          chname1.append(tmp)
      # chname = chname[1:]
      return chname1




    # Code with Papers functions
    def cop_desc(self,a):
      self.a = a
      desc = []
      for i in a:
        desc.append(i.find('p',attrs={'class':'item-strip-abstract'}).text)
      return desc

    def cop_codelinks(self,b):
      code = []
      github_code = []
      self.b = b

      for i in b:
        code.append( i.find('a',attrs={'class':'badge badge-dark'})['href'])

      base_url = 'https://paperswithcode.com'

      for i in range(len(code)):
        github_code.append('https://paperswithcode.com{}'.format(code[i]))
      return github_code

    def cop_titles(self,c):
      titles = []
      self.c = c
      for node in c:
          titles.append(''.join(node.findAll(text=True)))
      titles1 = titles[1:] # Because of the first content is coming as a str "Search Result"
      return titles1

    def html_urls(self,repos12):
      self.repos12 = repos12

      html_urls = []
      for i in repos12:
        html_urls.append(i.html_url)
      return html_urls

    def starslist(self,repos_name):
      self.repos_name = repos_name
      starslist1 = []
      for i in range(len(repos_name)):
            starslist = g.get_repo(repos_name[i])
            starslist1.append(starslist.stargazers_count)
      return starslist1


  class Sol:
    ob=Test()
    
    user = str(input("Enter the Keyword:"))

    qstr = quote(str(user))#%20
    req = Request('https://medium.com/search?q={0}'.format(qstr), headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    soup = BeautifulSoup(webpage)

    ## for code with papers
    qstr1  = quote_plus(user)#+
    req1 = Request('https://paperswithcode.com/search?q={0}'.format(qstr1), headers={'User-Agent': 'Mozilla/5.0'})
    webpage1 = urlopen(req1).read()
    soup1 = BeautifulSoup(webpage1)

    ## for Youtube
    qstr2  = quote_plus(user)
    req2 = Request("https://m.youtube.com/results?search_query={0}".format(qstr2), headers={'User-Agent': 'Mozilla/5.0'})
    webpage2 = urlopen(req2).read()
    soup2 = BeautifulSoup(webpage2)


    ## Github 
    repositories = g.search_repositories(query='topic:{0}'.format(user)) #need to solve for break iteraton

    try:
      repos =[]
      for repo in repositories:
          repos.append(repo.full_name)
      repos_name = repos[0:50]
    except Exception as ex:
      repos_name = repos[0:50]

    try:
      repos1 = []
      for repo in repositories:
          repos1.append(repo)
      repos12 = repos1[0:50]
    except Exception as ex:
      repos12 = repos1[0:50]

    y=soup.find_all('div',attrs= {'class':'postArticle-content'})
    x1=soup.findAll('span',attrs={'class':'u-relative u-background js-actionMultirecommendCount u-marginLeft5'})
    x2=soup.findAll('div',attrs={'class':'section-inner sectionLayout--insetColumn'})

    xy = soup2.findAll("div", "yt-lockup-byline")
    xy = xy[0:18]
    vids = soup2.findAll('a',attrs={'class':'yt-uix-tile-link'})

    res=ob.med_links(y)
    res1=ob.clapcount(x1)
    res2=ob.med_titles(x2)

    you1 = ob.videotitle(vids)
    you2 = ob.videourl(vids)
    you3 = ob.chname(xy)

    cop_desc = soup1.findAll('div',attrs={'class':'col-lg-9 item-content'})
    cop_codelinks =soup1.findAll('div',attrs={'class':'entity'})
    cop_titles = soup1.findAll('h1')

    cop1 = ob.cop_desc(cop_desc)
    cop2 = ob.cop_codelinks(cop_codelinks)
    cop3 = ob.cop_titles(cop_titles)

    a = ob.html_urls(repos12)
    b = ob.starslist(repos_name)
  ob1 = Sol()

  

#     print("\n######################################################")
#     return print("\nMedium-website contents")
#     print("\nFound {0} contents".format(len(res2)))
  return (ob1.res2,ob1.res,ob1.res)
#     print("Medium_clapcount",res1)
#     print("Medium_links",res)
#     print("\n######################################################")
#     print("\nYoutube contents")
#     print("\nFound {0} contents".format(len(you1)))
#     print("\nYoutube_titles",you1)
#     print("Youtube_links",you2)
#     print("Youtube_ch_titles",you3)
#     print("\n######################################################")
#     print("\nCode with Papers contents")
#     print("\nFound {0} contents".format(len(cop3)))
#     print("\nCode with Papers_titles",cop3)
#     print("Code with Papers_desc",cop1)
#     print("Code with Papers_codelinks",cop2)
#     print("\n######################################################")
#     print("\nGithub contents")
#     print("\nFound {0} contents".format(len(repos_name)))
#     print("\nGithub_repos_name",repos_name)
#     print("Github_links",a)
#     print("Github_starlist",b)

# %%
searching()
# Out:
# Enter the Keyword:nlp
# (['How to solve 90% of NLP problems: a step-by-step guideUsing Machine Learning to understand and…',
#   'Over 150 of the Best Machine Learning, NLP, and Python Tutorials I’ve\xa0FoundBy popular demand, I’ve updated this article with the latest tutorials from the past 12 months. Check it out\xa0here',
#   'Machine Learning, NLP: Text Classification using scikit-learn, python and\xa0NLTK.',
#   'Over 200 of the Best Machine Learning, NLP, and Python Tutorials\u200a-\u200a2018\xa0EditionThere are dozens\xa0of…',
#   'Ultimate Guide to Leveraging NLP & Machine Learning for your\xa0ChatbotCode Snippets and Github Included',
#   'NLP\u200a—\u200aBuilding a Question Answering modelDoing cool things with data!',
#   'BERT Explained: State of the art language model for\xa0NLP',
#   'Learning Machine Learning and NLP from 187 Quora QuestionsIf you like this article, check out another by Robbie:My Curated List of AI and Machine Learning Resources',
#   'Lessons Learned from Applying Deep Learning for NLP Without Big\xa0Data',
#   'How to get started in\xa0NLPSomewhere I read that if you ever have to answer the same question twice, it’s probably a good idea to turn it…'],
#  ['https://blog.insightdatascience.com/how-to-solve-90-of-nlp-problems-a-step-by-step-guide-fda605278e4e?source=search_post---------0',
#   'https://medium.com/machine-learning-in-practice/over-150-of-the-best-machine-learning-nlp-and-python-tutorials-ive-found-ffce2939bd78?source=search_post---------1',
#   'https://towardsdatascience.com/machine-learning-nlp-text-classification-using-scikit-learn-python-and-nltk-c52b92a7c73a?source=search_post---------2',
#   'https://medium.com/machine-learning-in-practice/over-200-of-the-best-machine-learning-nlp-and-python-tutorials-2018-edition-dd8cf53cb7dc?source=search_post---------3',
#   'https://chatbotslife.com/ultimate-guide-to-leveraging-nlp-machine-learning-for-you-chatbot-531ff2dd870c?source=search_post---------4',
#   'https://towardsdatascience.com/nlp-building-a-question-answering-model-ed0529a68c54?source=search_post---------5',
#   'https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270?source=search_post---------6',
#   'https://medium.com/machine-learning-in-practice/learning-machine-learning-and-nlp-from-185-quora-questions-cebe42e47da8?source=search_post---------7',
#   'https://towardsdatascience.com/lessons-learned-from-applying-deep-learning-for-nlp-without-big-data-d470db4f27bf?source=search_post---------8',
#   'https://towardsdatascience.com/how-to-get-started-in-nlp-6a62aa4eaeff?source=search_post---------9'])
